# %%
opcion = int(input("ingrese la opción 1.sumar/2.restar/3.multiplicar/4.dividir"))
numero1 = int(input("ingrese el numero1"))
numero2 = int(input("ingrese el numero2"))

if opcion == 1:
  resultado = numero1 + numero2
elif (opcion == 2):
  resultado = numero1 - numero2
elif (opcion == 3):
  resultado = numero1 * numero2
elif (opcion == 4):
  resultado = numero1 / numero2
else:
  print("ingrese una opción valida")

print("Resultado: ", resultado)
# Out:
# ingrese la opción 1.sumar/2.restar/3.multiplicar/4.dividir1
# ingrese el numero12
# ingrese el numero23
# Resultado:  5

# %%
radio =5.0
area= 3.1416 *(radio**2)
print("El área del círculo es ", area)
# Out:
# El área del círculo es  78.53999999999999

# %%
nombre="Ana"
edad=30
mensaje = "hola," + nombre+ ". Tienes " + str(edad) + "años."
print(mensaje)

#mensaje = "hola," + nombre+ ". Tienes " + edad + "años."
# Out:
# hola,Ana. Tienes 30años.

# %%
edad = 20
es_mayor = edad >= 18
if es_mayor:
   print("Es mayor de edad")
else:
   print("Es menor de edad")
# Out:
# Es mayor de edad

# %%
nombre = input("ingresa tu nombre: ")
edad = int(input("Ingresa tu edad: "))
altura = float(input("ingresa tu altura en metros: "))
mensaje = f"Hola, {nombre}. Tienes {edad} años y mides {altura} metros."
print(mensaje)
# Out:
# ingresa tu nombre: claudio
# Ingresa tu edad: 53
# ingresa tu altura en metros: 1.71
# Hola, claudio. Tienes 53 años y mides 1.71 metros.

# %%
nombre="Carlos"
edad=30
mensaje="Hola, " + nombre + ". Tienes " + str(edad) + " años."
print(mensaje)
# Out:
# Hola, Carlos. Tienes 30 años.

# %%
calificaciones = ["85", "90", "78", "92"]
suma = sum([int(nota) for nota in calificaciones])
promedio = suma /len(calificaciones)
print("Promedio:", promedio)
# Out:
# Promedio: 86.25

# %%
nombre=input("ingresa tu nombre: ")
edad=int(input("ingresa tu edad: "))
salario=float(input("ingresa tu salario: "))
mensaje= f"Hola, {nombre}. Tienes {edad} años y tu salario es ${salario:.2f}."
print(mensaje)
# Out:
# ingresa tu nombre: claudio
# ingresa tu edad: 53
# ingresa tu salario: 2000000
# Hola, claudio. Tienes 53 años y tu salario es $2000000.00.

# %%
a = 10
b = 3
suma = a + b
division_entera = a // b
potencia = a ** b
print("Suma:", suma)
print("División entera:", division_entera)
print("Potencia:", potencia)
# Out:
# Suma: 13
# División entera: 3
# Potencia: 1000

# %%
a = 8
b = 5
resultado = a > b
print("¿A es mayor que B?", resultado)
# Out:
# ¿A es mayor que B? True

# %%
edad = 20
es_adulto = edad >= 18
tiene_identificación = True
puede_entrar = es_adulto and tiene_identificación
print("¿Puede entrar?", puede_entrar)
# Out:
# ¿Puede entrar? True

# %%
precio = 120
descuento = 0.1
if precio > 100:
  precio -= precio * descuento
print("Precio final:", precio)
# Out:
# Precio final: 108.0

# %%
edad = 20
es_vip = True
if edad >= 18 or es_vip:
  print("Puede entrar al evento.")
else:
  print("No puede entrar al evento.")
# Out:
# Puede entrar al evento.

# %%
edad = 20
es_vip = True
if edad >= 18 and es_vip:
  print("Puede entrar al evento.")
else:
  print("No puede entrar al evento.")
# Out:
# Puede entrar al evento.

# %%
radio = 5
pi = 3.1416
area = pi * (radio ** 2)
print("Área del círculo:", area)
# Out:
# Área del círculo: 78.53999999999999

# %%
celsius = 25
fahrenheit = (celsius * 9/5) + 32
print("Temperatura en fahrenheit:", fahrenheit)
# Out:
# Temperatura en fahrenheit: 77.0

# %%
principal = 1000 # capital inicial
tasa_interes = 0.05  # tasa de interés
periodos = 10   # años
monto_final = principal * ((1 + tasa_interes) ** periodos)
print("Monto final después de 10 años", monto_final)
# Out:
# Monto final después de 10 años 1628.894626777442

# %%
nombre=input("ingresa tu nombre: ")
edad=int(input("ingresa tu edad: "))
pais=input("ingresa tu pais: ")
if edad >= 18 and (pais=="Argentina" or pais=="Chile" or pais=="Colombia"):
  print(f"Hola {nombre}, Ud puede a acceder a un beneficio por tener {edad} años y vivir en {pais}.")
else:
  print(f"Hola {nombre}, Ud no puede a acceder a un beneficio por no tener 18 años o porque no vive en Chile, Argentina o Colombia.")
# Out:
# ingresa tu nombre: Claudio
# ingresa tu edad: 53
# ingresa tu pais: Chile
# Hola Claudio, Ud puede a acceder a un beneficio por tener 53 años y vivir en Chile.

# %%
nombre = input("ingresa el nombre:")
edad = int(input("ingresa la edad:"))
pais = (input("ingresa el pais:")).lower()

paises = ["argentina", "chile", "colombia"]

if edad >= 18:
  if pais in paises:
    print (nombre, " puede acceder al beneficio")
  else:
    print (nombre, " no puede acceder al beneficio")
else:
  print (nombre, " no puede acceder al beneficio")
